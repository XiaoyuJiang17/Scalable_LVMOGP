# %%
import sys
sys.path.append('/Users/jiangxiaoyu/Desktop/All Projects/Scalable_LVMOGP/')
from code_blocks.our_models.Multi_ISVGP import Multi_Variational_IGP
from run_experiments.prepare_dataset import *
import yaml
import torch
import numpy as np
from torch import Tensor
from utils_general import *

# %%
def load_model_and_likelihoods(multi_variational_igp, filename):
    state_dicts = torch.load(filename)
    for model, state_dict in zip(multi_variational_igp.models, state_dicts['models']):
        model.load_state_dict(state_dict)
    for likelihood, state_dict in zip(multi_variational_igp.likelihoods, state_dicts['likelihoods']):
        likelihood.load_state_dict(state_dict)

# %% [markdown]
# ## Load in model

# %%
config_file = '/Users/jiangxiaoyu/Desktop/All Projects/Scalable_LVMOGP/configs/synthetic_IGP/Scale_RBF/IndepSVGP_50_outputs_unfix.yaml'
model_and_likelihood_path = '/Users/jiangxiaoyu/Desktop/All Projects/Scalable_LVMOGP/experiments_results/synthetic_IGP/Scale_RBF/IndepSVGP_50_outputs_unfix/2024-02-23_23:26:15/MultiIGPs_models_and_likelihoods.pth'

# %%
with open(config_file, 'r') as file:
    config = yaml.safe_load(file)

MultiIGP = Multi_Variational_IGP(
        num_models = config['n_outputs'], 
        inducing_points = Tensor(np.linspace(config['init_inducing_input_LB'], config['init_inducing_input_UB'], config['n_inducing_input']).reshape(-1, 1)), 
        init_likelihood_noise = config['init_likelihood_noise'], 
        kernel_type = config['input_kernel_type'], 
        learn_inducing_locations= config['learn_inducing_locations_input'],
        input_dim = config['input_dim']
    )

load_model_and_likelihoods(MultiIGP, model_and_likelihood_path)

# %% [markdown]
# ## Load in data

# %%
if config['dataset_type'] == 'synthetic_regression':
        data_inputs, data_Y_squeezed, ls_of_ls_train_input, ls_of_ls_test_input, train_sample_idx_ls, test_sample_idx_ls = prepare_synthetic_regression_data(config)
        means, stds = None, None

# %% [markdown]
# ## Test

# %%
# The following piece of code copied from training_IGP.py file.
'''$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$'''
# The following lists consist of datasets for all outputs.
list_train_X, list_train_Y = [], [] 
list_test_X, list_test_Y = [], []

# split data_Y_squeezed into train/test part. NOTE: that's train/test target data for all outputs.
data_Y_train_squeezed = data_Y_squeezed[train_sample_idx_ls]
data_Y_test_squeezed = data_Y_squeezed[test_sample_idx_ls]

n_input_test = config['n_input'] - config['n_input_train']
##### ------------------------------------------------------------------------
for i in range(config['n_outputs']):
    # start and end for current output, idx used to pick data for only current output
    idgp_train_start = i * config['n_input_train']
    idgp_train_end = idgp_train_start + config['n_input_train']

    idgp_test_start = i * n_input_test
    idgp_test_end = idgp_test_start + n_input_test

    # training data for current output
    train_X = data_inputs[ls_of_ls_train_input[i]]
    train_Y = data_Y_train_squeezed[idgp_train_start:idgp_train_end]
    assert train_X.shape ==  train_Y.shape == torch.Size([config['n_input_train']])
    list_train_X.append(train_X)
    list_train_Y.append(train_Y)

    # testing data for current output
    test_X = data_inputs[ls_of_ls_test_input[i]]
    test_Y = data_Y_test_squeezed[idgp_test_start:idgp_test_end]
    assert test_X.shape ==  test_Y.shape == torch.Size([n_input_test])
    list_test_X.append(test_X)
    list_test_Y.append(test_Y)
'''$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$'''
# Out:
# '$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$'

# %%
# for compute overall (all outputs) performance
train_error_square_sum = 0.
test_error_square_sum = 0.
train_error_length = 0.
test_error_length = 0.
train_nll_sum = 0.
test_nll_sum = 0.

# For visualization
n_points4visualization = 500
tensor_inputs4visualization = Tensor(np.linspace(config['min_input_bound'], config['max_input_bound'], n_points4visualization).reshape(-1, 1)) 
list_train_output_dist = []
list_test_output_dist = []
list_output_dist4visual = []

for j in range(config['n_outputs']):
    curr_model = MultiIGP.get_model(j)
    curr_likelihood = MultiIGP.get_likelihood(j)

    # Inference for train and test data
    curr_train_output_dist = curr_likelihood(curr_model(list_train_X[j]))
    curr_test_output_dist  = curr_likelihood(curr_model(list_test_X[j]))

    # Inference for data points for visualization
    visual_output_dist = curr_likelihood(curr_model(tensor_inputs4visualization))

    # store them for following visualization
    # list_train_output_dist.append(curr_train_output_dist)
    # list_test_output_dist.append(curr_test_output_dist)
    list_output_dist4visual.append(visual_output_dist)

    # RMSE
    curr_train_suqare_errors = (curr_train_output_dist.loc.detach() - list_train_Y[j]).square()
    curr_test_square_errors = (curr_test_output_dist.loc.detach() - list_test_Y[j]).square()
    train_error_square_sum += curr_train_suqare_errors.sum()
    test_error_square_sum  += curr_test_square_errors.sum()
    print('-----' * 10)
    print(str(j) + 'th Model Train RMSE: ', curr_train_suqare_errors.mean().sqrt())
    print(str(j) + 'th Model Test RMSE: ', curr_test_square_errors.mean().sqrt())

    # NLL
    train_nll_ = neg_log_likelihood(list_train_Y[j], curr_train_output_dist.loc.detach(), curr_train_output_dist.variance.detach())
    test_nll_ = neg_log_likelihood(list_test_Y[j], curr_test_output_dist.loc.detach(), curr_test_output_dist.variance.detach())
    train_nll_sum += train_nll_ * len(list_train_Y[j])
    test_nll_sum  += test_nll_ *  len(list_test_Y[j])
    print(str(j) + 'th Model Train NLL: ', train_nll_)
    print(str(j) + 'th Model Test NLL: ', test_nll_)

    train_error_length += len(list_train_Y[j])
    test_error_length += len(list_test_Y[j])


print('#######' * 10)
print('Global Train RMSE', (train_error_square_sum / train_error_length).sqrt())
print('Global Test RMSE', (test_error_square_sum / test_error_length).sqrt())
print('Global Train NLL', train_nll_sum / train_error_length)
print('Global Test NLL', test_nll_sum / test_error_length)
# Out:
# --------------------------------------------------
# 0th Model Train RMSE:  tensor(0.1186)
# 0th Model Test RMSE:  tensor(0.6921)
# 0th Model Train NLL:  tensor(-0.2846)
# 0th Model Test NLL:  tensor(0.8548)
# --------------------------------------------------
# 1th Model Train RMSE:  tensor(0.2091)
# 1th Model Test RMSE:  tensor(0.8391)
# 1th Model Train NLL:  tensor(0.1206)
# 1th Model Test NLL:  tensor(1.3133)
# --------------------------------------------------
# 2th Model Train RMSE:  tensor(0.2208)
# 2th Model Test RMSE:  tensor(0.6169)
# 2th Model Train NLL:  tensor(0.1951)
# 2th Model Test NLL:  tensor(0.8012)
# --------------------------------------------------
# 3th Model Train RMSE:  tensor(0.1606)
# 3th Model Test RMSE:  tensor(0.4283)
# 3th Model Train NLL:  tensor(0.1572)
# 3th Model Test NLL:  tensor(0.7401)
# --------------------------------------------------
# 4th Model Train RMSE:  tensor(0.1554)
# 4th Model Test RMSE:  tensor(0.5543)
# 4th Model Train NLL:  tensor(0.0059)
# 4th Model Test NLL:  tensor(0.8905)
# --------------------------------------------------
# 5th Model Train RMSE:  tensor(0.6440)
# 5th Model Test RMSE:  tensor(1.1026)
# 5th Model Train NLL:  tensor(0.9610)
# 5th Model Test NLL:  tensor(1.8734)
# --------------------------------------------------
# 6th Model Train RMSE:  tensor(0.2064)
# 6th Model Test RMSE:  tensor(0.5478)
# 6th Model Train NLL:  tensor(0.1683)
# 6th Model Test NLL:  tensor(0.8096)
# --------------------------------------------------
# 7th Model Train RMSE:  tensor(0.1034)
# 7th Model Test RMSE:  tensor(0.7775)
# 7th Model Train NLL:  tensor(-0.3418)
# 7th Model Test NLL:  tensor(1.0423)
# --------------------------------------------------
# 8th Model Train RMSE:  tensor(0.0716)
# 8th Model Test RMSE:  tensor(0.3689)
# 8th Model Train NLL:  tensor(-0.5748)
# 8th Model Test NLL:  tensor(0.4675)
# --------------------------------------------------
# 9th Model Train RMSE:  tensor(0.1462)
# 9th Model Test RMSE:  tensor(0.4996)
# 9th Model Train NLL:  tensor(-0.1162)
# 9th Model Test NLL:  tensor(0.7682)
# --------------------------------------------------
# 10th Model Train RMSE:  tensor(0.2845)
# 10th Model Test RMSE:  tensor(0.5381)
# 10th Model Train NLL:  tensor(0.3659)
# 10th Model Test NLL:  tensor(0.8188)
# --------------------------------------------------
# 11th Model Train RMSE:  tensor(0.2849)
# 11th Model Test RMSE:  tensor(0.4857)
# 11th Model Train NLL:  tensor(0.4958)
# 11th Model Test NLL:  tensor(0.8038)
# --------------------------------------------------
# 12th Model Train RMSE:  tensor(0.0909)
# 12th Model Test RMSE:  tensor(0.4141)
# 12th Model Train NLL:  tensor(-0.5299)
# 12th Model Test NLL:  tensor(0.4792)
# --------------------------------------------------
# 13th Model Train RMSE:  tensor(0.1128)
# 13th Model Test RMSE:  tensor(0.6128)
# 13th Model Train NLL:  tensor(-0.2329)
# 13th Model Test NLL:  tensor(0.8329)
# --------------------------------------------------
# 14th Model Train RMSE:  tensor(0.1138)
# 14th Model Test RMSE:  tensor(0.8379)
# 14th Model Train NLL:  tensor(-0.3290)
# 14th Model Test NLL:  tensor(0.9545)
# --------------------------------------------------
# 15th Model Train RMSE:  tensor(0.1733)
# 15th Model Test RMSE:  tensor(0.7998)
# 15th Model Train NLL:  tensor(0.0014)
# 15th Model Test NLL:  tensor(1.1494)
# --------------------------------------------------
# 16th Model Train RMSE:  tensor(0.1560)
# 16th Model Test RMSE:  tensor(0.5962)
# 16th Model Train NLL:  tensor(-0.0523)
# 16th Model Test NLL:  tensor(0.9328)
# --------------------------------------------------
# 17th Model Train RMSE:  tensor(0.1111)
# 17th Model Test RMSE:  tensor(0.4783)
# 17th Model Train NLL:  tensor(-0.3769)
# 17th Model Test NLL:  tensor(0.5134)
# --------------------------------------------------
# 18th Model Train RMSE:  tensor(0.1395)
# 18th Model Test RMSE:  tensor(0.4069)
# 18th Model Train NLL:  tensor(-0.0398)
# 18th Model Test NLL:  tensor(0.6704)
# --------------------------------------------------
# 19th Model Train RMSE:  tensor(0.1396)
# 19th Model Test RMSE:  tensor(0.5536)
# 19th Model Train NLL:  tensor(0.0046)
# 19th Model Test NLL:  tensor(0.7104)
# --------------------------------------------------
# 20th Model Train RMSE:  tensor(0.3228)
# 20th Model Test RMSE:  tensor(0.5837)
# 20th Model Train NLL:  tensor(0.5056)
# 20th Model Test NLL:  tensor(0.8455)
# --------------------------------------------------
# 21th Model Train RMSE:  tensor(0.1496)
# 21th Model Test RMSE:  tensor(0.4589)
# 21th Model Train NLL:  tensor(-0.0186)
# 21th Model Test NLL:  tensor(0.7033)
# --------------------------------------------------
# 22th Model Train RMSE:  tensor(0.1247)
# 22th Model Test RMSE:  tensor(0.3288)
# 22th Model Train NLL:  tensor(-0.1411)
# 22th Model Test NLL:  tensor(0.6116)
# --------------------------------------------------
# 23th Model Train RMSE:  tensor(0.0707)
# 23th Model Test RMSE:  tensor(0.4245)
# 23th Model Train NLL:  tensor(-0.6400)
# 23th Model Test NLL:  tensor(0.8530)
# --------------------------------------------------
# 24th Model Train RMSE:  tensor(0.2069)
# 24th Model Test RMSE:  tensor(0.6805)
# 24th Model Train NLL:  tensor(0.2073)
# 24th Model Test NLL:  tensor(0.8470)
# --------------------------------------------------
# 25th Model Train RMSE:  tensor(0.1852)
# 25th Model Test RMSE:  tensor(0.4566)
# 25th Model Train NLL:  tensor(0.1951)
# 25th Model Test NLL:  tensor(0.6662)
# --------------------------------------------------
# 26th Model Train RMSE:  tensor(0.1810)
# 26th Model Test RMSE:  tensor(0.2730)
# 26th Model Train NLL:  tensor(0.0344)
# 26th Model Test NLL:  tensor(0.2397)
# --------------------------------------------------
# 27th Model Train RMSE:  tensor(0.1386)
# 27th Model Test RMSE:  tensor(0.6856)
# 27th Model Train NLL:  tensor(-0.2756)
# 27th Model Test NLL:  tensor(1.0545)
# --------------------------------------------------
# 28th Model Train RMSE:  tensor(0.1497)
# 28th Model Test RMSE:  tensor(0.6253)
# 28th Model Train NLL:  tensor(-0.0872)
# 28th Model Test NLL:  tensor(0.8094)
# --------------------------------------------------
# 29th Model Train RMSE:  tensor(0.1089)
# 29th Model Test RMSE:  tensor(0.3314)
# 29th Model Train NLL:  tensor(-0.2127)
# 29th Model Test NLL:  tensor(0.2634)
# --------------------------------------------------
# 30th Model Train RMSE:  tensor(0.1112)
# 30th Model Test RMSE:  tensor(0.3909)
# 30th Model Train NLL:  tensor(-0.3303)
# 30th Model Test NLL:  tensor(0.5667)
# --------------------------------------------------
# 31th Model Train RMSE:  tensor(0.1934)
# 31th Model Test RMSE:  tensor(0.5313)
# 31th Model Train NLL:  tensor(0.0424)
# 31th Model Test NLL:  tensor(0.7625)
# --------------------------------------------------
# 32th Model Train RMSE:  tensor(0.2945)
# 32th Model Test RMSE:  tensor(0.6186)
# 32th Model Train NLL:  tensor(0.3224)
# 32th Model Test NLL:  tensor(0.8274)
# --------------------------------------------------
# 33th Model Train RMSE:  tensor(0.1670)
# 33th Model Test RMSE:  tensor(0.3885)
# 33th Model Train NLL:  tensor(0.1379)
# 33th Model Test NLL:  tensor(0.5725)
# --------------------------------------------------
# 34th Model Train RMSE:  tensor(0.1642)
# 34th Model Test RMSE:  tensor(0.3463)
# 34th Model Train NLL:  tensor(0.0006)
# 34th Model Test NLL:  tensor(0.3777)
# --------------------------------------------------
# 35th Model Train RMSE:  tensor(0.1280)
# 35th Model Test RMSE:  tensor(0.5780)
# 35th Model Train NLL:  tensor(-0.2264)
# 35th Model Test NLL:  tensor(0.7261)
# --------------------------------------------------
# 36th Model Train RMSE:  tensor(0.1933)
# 36th Model Test RMSE:  tensor(0.6113)
# 36th Model Train NLL:  tensor(0.0875)
# 36th Model Test NLL:  tensor(0.9554)
# --------------------------------------------------
# 37th Model Train RMSE:  tensor(0.2260)
# 37th Model Test RMSE:  tensor(0.6954)
# 37th Model Train NLL:  tensor(0.2497)
# 37th Model Test NLL:  tensor(1.1100)
# --------------------------------------------------
# 38th Model Train RMSE:  tensor(0.1355)
# 38th Model Test RMSE:  tensor(0.5242)
# 38th Model Train NLL:  tensor(-0.1284)
# 38th Model Test NLL:  tensor(0.7993)
# --------------------------------------------------
# 39th Model Train RMSE:  tensor(0.2834)
# 39th Model Test RMSE:  tensor(0.5038)
# 39th Model Train NLL:  tensor(0.3607)
# 39th Model Test NLL:  tensor(0.7233)
# --------------------------------------------------
# 40th Model Train RMSE:  tensor(0.1781)
# 40th Model Test RMSE:  tensor(0.6312)
# 40th Model Train NLL:  tensor(0.0425)
# 40th Model Test NLL:  tensor(0.7754)
# --------------------------------------------------
# 41th Model Train RMSE:  tensor(0.2058)
# 41th Model Test RMSE:  tensor(0.8569)
# 41th Model Train NLL:  tensor(0.1443)
# 41th Model Test NLL:  tensor(1.2355)
# --------------------------------------------------
# 42th Model Train RMSE:  tensor(0.1719)
# 42th Model Test RMSE:  tensor(0.4096)
# 42th Model Train NLL:  tensor(0.1092)
# 42th Model Test NLL:  tensor(0.6092)
# --------------------------------------------------
# 43th Model Train RMSE:  tensor(0.1577)
# 43th Model Test RMSE:  tensor(0.4005)
# 43th Model Train NLL:  tensor(0.0444)
# 43th Model Test NLL:  tensor(0.5936)
# --------------------------------------------------
# 44th Model Train RMSE:  tensor(0.1720)
# 44th Model Test RMSE:  tensor(0.5548)
# 44th Model Train NLL:  tensor(0.0963)
# 44th Model Test NLL:  tensor(0.6808)
# --------------------------------------------------
# 45th Model Train RMSE:  tensor(0.1317)
# 45th Model Test RMSE:  tensor(0.6610)
# 45th Model Train NLL:  tensor(-0.2286)
# 45th Model Test NLL:  tensor(1.0418)
# --------------------------------------------------
# 46th Model Train RMSE:  tensor(0.2609)
# 46th Model Test RMSE:  tensor(0.3287)
# 46th Model Train NLL:  tensor(0.3248)
# 46th Model Test NLL:  tensor(0.4947)
# --------------------------------------------------
# 47th Model Train RMSE:  tensor(0.2329)
# 47th Model Test RMSE:  tensor(0.5460)
# 47th Model Train NLL:  tensor(0.2303)
# 47th Model Test NLL:  tensor(0.6239)
# --------------------------------------------------
# 48th Model Train RMSE:  tensor(0.0745)
# 48th Model Test RMSE:  tensor(0.6682)
# 48th Model Train NLL:  tensor(-0.5921)
# 48th Model Test NLL:  tensor(1.3430)
# --------------------------------------------------
# 49th Model Train RMSE:  tensor(0.2296)
# 49th Model Test RMSE:  tensor(0.4523)
# 49th Model Train NLL:  tensor(0.2986)
# 49th Model Test NLL:  tensor(0.7094)
# ######################################################################
# Global Train RMSE tensor(0.2007)
# Global Test RMSE tensor(0.5772)
# Global Train NLL tensor(0.0030)
# Global Test NLL tensor(0.7970)

# %% [markdown]
# ## Plot

# %%
picked_index = 15

plot_traindata_testdata_fittedgp(train_X=list_train_X[picked_index], 
                                 train_Y=list_train_Y[picked_index], 
                                 test_X=list_test_X[picked_index], 
                                 test_Y=list_test_Y[picked_index], 
                                 gp_X=tensor_inputs4visualization, 
                                 gp_pred_mean=list_output_dist4visual[picked_index].loc.detach(), 
                                 gp_pred_std=list_output_dist4visual[picked_index].stddev.detach(), 
                                 inducing_points_X=MultiIGP.get_model(picked_index).variational_strategy.inducing_points.detach(), 
                                 n_inducing_C=config['n_inducing_input']) # NOTE: input is C not X
