# %%
import sys
sys.path.append('/Users/jiangxiaoyu/Desktop/All Projects/Scalable_LVMOGP/')
from code_blocks.our_models.Multi_ISVGP import Multi_Variational_IGP
from run_experiments.prepare_dataset import *
import yaml
import torch
import numpy as np
from torch import Tensor
from utils_general import *

# %%
torch.set_default_dtype(torch.float64)

# %%
def load_model_and_likelihoods(multi_variational_igp, filename):
    state_dicts = torch.load(filename)
    for model, state_dict in zip(multi_variational_igp.models, state_dicts['models']):
        model.load_state_dict(state_dict)
    for likelihood, state_dict in zip(multi_variational_igp.likelihoods, state_dicts['likelihoods']):
        likelihood.load_state_dict(state_dict)

# %% [markdown]
# ## Load in model

# %%
config_file = '/Users/jiangxiaoyu/Desktop/All Projects/Scalable_LVMOGP/configs/synthetic_IGP/Scale_RBF/IndepSVGP_50_outputs_unfix.yaml'
model_and_likelihood_path = '/Users/jiangxiaoyu/Desktop/All Projects/Scalable_LVMOGP/experiments_results/synthetic_IGP/Scale_RBF/IndepSVGP_50_outputs_unfix/2024-03-04_12:25:14/MultiIGPs_models_and_likelihoods.pth'

# %%
with open(config_file, 'r') as file:
    config = yaml.safe_load(file)

MultiIGP = Multi_Variational_IGP(
        num_models = config['n_outputs'], 
        inducing_points = Tensor(np.linspace(config['init_inducing_input_LB'], config['init_inducing_input_UB'], config['n_inducing_input']).reshape(-1, 1)), 
        init_likelihood_noise = config['init_likelihood_noise'], 
        kernel_type = config['input_kernel_type'], 
        learn_inducing_locations= config['learn_inducing_locations_input'],
        input_dim = config['input_dim']
    )

load_model_and_likelihoods(MultiIGP, model_and_likelihood_path)

# %% [markdown]
# ## Load in data

# %%
if config['dataset_type'] == 'synthetic_regression':
        data_inputs, data_Y_squeezed, ls_of_ls_train_input, ls_of_ls_test_input, train_sample_idx_ls, test_sample_idx_ls = prepare_synthetic_regression_data(config)
        means, stds = None, None

# %% [markdown]
# ## Test

# %%
# The following piece of code copied from training_IGP.py file.
'''$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$'''
# The following lists consist of datasets for all outputs.
list_train_X, list_train_Y = [], [] 
list_test_X, list_test_Y = [], []

# split data_Y_squeezed into train/test part. NOTE: that's train/test target data for all outputs.
data_Y_train_squeezed = data_Y_squeezed[train_sample_idx_ls]
data_Y_test_squeezed = data_Y_squeezed[test_sample_idx_ls]

n_input_test = config['n_input'] - config['n_input_train']
##### ------------------------------------------------------------------------
for i in range(config['n_outputs']):
    # start and end for current output, idx used to pick data for only current output
    idgp_train_start = i * config['n_input_train']
    idgp_train_end = idgp_train_start + config['n_input_train']

    idgp_test_start = i * n_input_test
    idgp_test_end = idgp_test_start + n_input_test

    # training data for current output
    train_X = data_inputs[ls_of_ls_train_input[i]]
    train_Y = data_Y_train_squeezed[idgp_train_start:idgp_train_end]
    assert train_X.shape ==  train_Y.shape == torch.Size([config['n_input_train']])
    list_train_X.append(train_X)
    list_train_Y.append(train_Y)

    # testing data for current output
    test_X = data_inputs[ls_of_ls_test_input[i]]
    test_Y = data_Y_test_squeezed[idgp_test_start:idgp_test_end]
    assert test_X.shape ==  test_Y.shape == torch.Size([n_input_test])
    list_test_X.append(test_X)
    list_test_Y.append(test_Y)
'''$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$'''
# Out:
# '$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$'

# %%
# for compute overall (all outputs) performance
train_error_square_sum = 0.
test_error_square_sum = 0.
train_error_length = 0.
test_error_length = 0.
train_nll_sum = 0.
test_nll_sum = 0.

# For visualization
n_points4visualization = 500
tensor_inputs4visualization = Tensor(np.linspace(config['min_input_bound'], config['max_input_bound'], n_points4visualization).reshape(-1, 1)) 
list_train_output_dist = []
list_test_output_dist = []
list_output_dist4visual = []

for j in range(config['n_outputs']):
    curr_model = MultiIGP.get_model(j)
    curr_likelihood = MultiIGP.get_likelihood(j)

    # Inference for train and test data
    curr_train_output_dist = curr_likelihood(curr_model(list_train_X[j]))
    curr_test_output_dist  = curr_likelihood(curr_model(list_test_X[j]))

    # Inference for data points for visualization
    visual_output_dist = curr_likelihood(curr_model(tensor_inputs4visualization))

    # store them for following visualization
    # list_train_output_dist.append(curr_train_output_dist)
    # list_test_output_dist.append(curr_test_output_dist)
    list_output_dist4visual.append(visual_output_dist)

    # RMSE
    curr_train_suqare_errors = (curr_train_output_dist.loc.detach() - list_train_Y[j]).square()
    curr_test_square_errors = (curr_test_output_dist.loc.detach() - list_test_Y[j]).square()
    train_error_square_sum += curr_train_suqare_errors.sum()
    test_error_square_sum  += curr_test_square_errors.sum()
    print('-----' * 10)
    print(str(j) + 'th Model Train RMSE: ', curr_train_suqare_errors.mean().sqrt())
    print(str(j) + 'th Model Test RMSE: ', curr_test_square_errors.mean().sqrt())

    # NLL
    train_nll_ = neg_log_likelihood(list_train_Y[j], curr_train_output_dist.loc.detach(), curr_train_output_dist.variance.detach())
    test_nll_ = neg_log_likelihood(list_test_Y[j], curr_test_output_dist.loc.detach(), curr_test_output_dist.variance.detach())
    train_nll_sum += train_nll_ * len(list_train_Y[j])
    test_nll_sum  += test_nll_ *  len(list_test_Y[j])
    print(str(j) + 'th Model Train NLL: ', train_nll_)
    print(str(j) + 'th Model Test NLL: ', test_nll_)

    train_error_length += len(list_train_Y[j])
    test_error_length += len(list_test_Y[j])


print('#######' * 10)
print('Global Train RMSE', (train_error_square_sum / train_error_length).sqrt())
print('Global Test RMSE', (test_error_square_sum / test_error_length).sqrt())
print('Global Train NLL', train_nll_sum / train_error_length)
print('Global Test NLL', test_nll_sum / test_error_length)
# Out:
# --------------------------------------------------
# 0th Model Train RMSE:  tensor(0.1237, dtype=torch.float64)
# 0th Model Test RMSE:  tensor(0.6913, dtype=torch.float64)
# 0th Model Train NLL:  tensor(-0.2641, dtype=torch.float64)
# 0th Model Test NLL:  tensor(0.8733, dtype=torch.float64)
# --------------------------------------------------
# 1th Model Train RMSE:  tensor(0.2121, dtype=torch.float64)
# 1th Model Test RMSE:  tensor(0.8416, dtype=torch.float64)
# 1th Model Train NLL:  tensor(0.1237, dtype=torch.float64)
# 1th Model Test NLL:  tensor(1.3296, dtype=torch.float64)
# --------------------------------------------------
# 2th Model Train RMSE:  tensor(0.2240, dtype=torch.float64)
# 2th Model Test RMSE:  tensor(0.6198, dtype=torch.float64)
# 2th Model Train NLL:  tensor(0.2105, dtype=torch.float64)
# 2th Model Test NLL:  tensor(0.8061, dtype=torch.float64)
# --------------------------------------------------
# 3th Model Train RMSE:  tensor(0.1641, dtype=torch.float64)
# 3th Model Test RMSE:  tensor(0.4277, dtype=torch.float64)
# 3th Model Train NLL:  tensor(0.1658, dtype=torch.float64)
# 3th Model Test NLL:  tensor(0.7372, dtype=torch.float64)
# --------------------------------------------------
# 4th Model Train RMSE:  tensor(0.1589, dtype=torch.float64)
# 4th Model Test RMSE:  tensor(0.5483, dtype=torch.float64)
# 4th Model Train NLL:  tensor(-0.0018, dtype=torch.float64)
# 4th Model Test NLL:  tensor(0.8722, dtype=torch.float64)
# --------------------------------------------------
# 5th Model Train RMSE:  tensor(0.6037, dtype=torch.float64)
# 5th Model Test RMSE:  tensor(1.0533, dtype=torch.float64)
# 5th Model Train NLL:  tensor(0.8987, dtype=torch.float64)
# 5th Model Test NLL:  tensor(1.7347, dtype=torch.float64)
# --------------------------------------------------
# 6th Model Train RMSE:  tensor(0.2087, dtype=torch.float64)
# 6th Model Test RMSE:  tensor(0.5528, dtype=torch.float64)
# 6th Model Train NLL:  tensor(0.1815, dtype=torch.float64)
# 6th Model Test NLL:  tensor(0.8227, dtype=torch.float64)
# --------------------------------------------------
# 7th Model Train RMSE:  tensor(0.1052, dtype=torch.float64)
# 7th Model Test RMSE:  tensor(0.7713, dtype=torch.float64)
# 7th Model Train NLL:  tensor(-0.3308, dtype=torch.float64)
# 7th Model Test NLL:  tensor(1.0162, dtype=torch.float64)
# --------------------------------------------------
# 8th Model Train RMSE:  tensor(0.0738, dtype=torch.float64)
# 8th Model Test RMSE:  tensor(0.3682, dtype=torch.float64)
# 8th Model Train NLL:  tensor(-0.5608, dtype=torch.float64)
# 8th Model Test NLL:  tensor(0.4778, dtype=torch.float64)
# --------------------------------------------------
# 9th Model Train RMSE:  tensor(0.2506, dtype=torch.float64)
# 9th Model Test RMSE:  tensor(0.5265, dtype=torch.float64)
# 9th Model Train NLL:  tensor(0.2117, dtype=torch.float64)
# 9th Model Test NLL:  tensor(0.7978, dtype=torch.float64)
# --------------------------------------------------
# 10th Model Train RMSE:  tensor(0.2923, dtype=torch.float64)
# 10th Model Test RMSE:  tensor(0.5457, dtype=torch.float64)
# 10th Model Train NLL:  tensor(0.3881, dtype=torch.float64)
# 10th Model Test NLL:  tensor(0.8324, dtype=torch.float64)
# --------------------------------------------------
# 11th Model Train RMSE:  tensor(0.3005, dtype=torch.float64)
# 11th Model Test RMSE:  tensor(0.4990, dtype=torch.float64)
# 11th Model Train NLL:  tensor(0.5454, dtype=torch.float64)
# 11th Model Test NLL:  tensor(0.8305, dtype=torch.float64)
# --------------------------------------------------
# 12th Model Train RMSE:  tensor(0.0909, dtype=torch.float64)
# 12th Model Test RMSE:  tensor(0.4153, dtype=torch.float64)
# 12th Model Train NLL:  tensor(-0.5233, dtype=torch.float64)
# 12th Model Test NLL:  tensor(0.4878, dtype=torch.float64)
# --------------------------------------------------
# 13th Model Train RMSE:  tensor(0.1222, dtype=torch.float64)
# 13th Model Test RMSE:  tensor(0.6203, dtype=torch.float64)
# 13th Model Train NLL:  tensor(-0.1880, dtype=torch.float64)
# 13th Model Test NLL:  tensor(0.8442, dtype=torch.float64)
# --------------------------------------------------
# 14th Model Train RMSE:  tensor(0.1180, dtype=torch.float64)
# 14th Model Test RMSE:  tensor(0.8267, dtype=torch.float64)
# 14th Model Train NLL:  tensor(-0.3224, dtype=torch.float64)
# 14th Model Test NLL:  tensor(0.9463, dtype=torch.float64)
# --------------------------------------------------
# 15th Model Train RMSE:  tensor(0.2080, dtype=torch.float64)
# 15th Model Test RMSE:  tensor(0.8014, dtype=torch.float64)
# 15th Model Train NLL:  tensor(0.1066, dtype=torch.float64)
# 15th Model Test NLL:  tensor(1.1777, dtype=torch.float64)
# --------------------------------------------------
# 16th Model Train RMSE:  tensor(0.1632, dtype=torch.float64)
# 16th Model Test RMSE:  tensor(0.5989, dtype=torch.float64)
# 16th Model Train NLL:  tensor(-0.0530, dtype=torch.float64)
# 16th Model Test NLL:  tensor(0.9419, dtype=torch.float64)
# --------------------------------------------------
# 17th Model Train RMSE:  tensor(0.1105, dtype=torch.float64)
# 17th Model Test RMSE:  tensor(0.4902, dtype=torch.float64)
# 17th Model Train NLL:  tensor(-0.3546, dtype=torch.float64)
# 17th Model Test NLL:  tensor(0.5496, dtype=torch.float64)
# --------------------------------------------------
# 18th Model Train RMSE:  tensor(0.1392, dtype=torch.float64)
# 18th Model Test RMSE:  tensor(0.4100, dtype=torch.float64)
# 18th Model Train NLL:  tensor(-0.0545, dtype=torch.float64)
# 18th Model Test NLL:  tensor(0.6658, dtype=torch.float64)
# --------------------------------------------------
# 19th Model Train RMSE:  tensor(0.1518, dtype=torch.float64)
# 19th Model Test RMSE:  tensor(0.5424, dtype=torch.float64)
# 19th Model Train NLL:  tensor(0.0616, dtype=torch.float64)
# 19th Model Test NLL:  tensor(0.6960, dtype=torch.float64)
# --------------------------------------------------
# 20th Model Train RMSE:  tensor(0.3378, dtype=torch.float64)
# 20th Model Test RMSE:  tensor(0.6053, dtype=torch.float64)
# 20th Model Train NLL:  tensor(0.5539, dtype=torch.float64)
# 20th Model Test NLL:  tensor(0.8815, dtype=torch.float64)
# --------------------------------------------------
# 21th Model Train RMSE:  tensor(0.1521, dtype=torch.float64)
# 21th Model Test RMSE:  tensor(0.4578, dtype=torch.float64)
# 21th Model Train NLL:  tensor(-0.0222, dtype=torch.float64)
# 21th Model Test NLL:  tensor(0.7077, dtype=torch.float64)
# --------------------------------------------------
# 22th Model Train RMSE:  tensor(0.1373, dtype=torch.float64)
# 22th Model Test RMSE:  tensor(0.3057, dtype=torch.float64)
# 22th Model Train NLL:  tensor(-0.0774, dtype=torch.float64)
# 22th Model Test NLL:  tensor(0.5865, dtype=torch.float64)
# --------------------------------------------------
# 23th Model Train RMSE:  tensor(0.0741, dtype=torch.float64)
# 23th Model Test RMSE:  tensor(0.4178, dtype=torch.float64)
# 23th Model Train NLL:  tensor(-0.5876, dtype=torch.float64)
# 23th Model Test NLL:  tensor(0.7581, dtype=torch.float64)
# --------------------------------------------------
# 24th Model Train RMSE:  tensor(0.2241, dtype=torch.float64)
# 24th Model Test RMSE:  tensor(0.6808, dtype=torch.float64)
# 24th Model Train NLL:  tensor(0.2584, dtype=torch.float64)
# 24th Model Test NLL:  tensor(0.8658, dtype=torch.float64)
# --------------------------------------------------
# 25th Model Train RMSE:  tensor(0.2077, dtype=torch.float64)
# 25th Model Test RMSE:  tensor(0.4725, dtype=torch.float64)
# 25th Model Train NLL:  tensor(0.2598, dtype=torch.float64)
# 25th Model Test NLL:  tensor(0.6975, dtype=torch.float64)
# --------------------------------------------------
# 26th Model Train RMSE:  tensor(0.1840, dtype=torch.float64)
# 26th Model Test RMSE:  tensor(0.2666, dtype=torch.float64)
# 26th Model Train NLL:  tensor(0.0474, dtype=torch.float64)
# 26th Model Test NLL:  tensor(0.2342, dtype=torch.float64)
# --------------------------------------------------
# 27th Model Train RMSE:  tensor(0.1388, dtype=torch.float64)
# 27th Model Test RMSE:  tensor(0.6898, dtype=torch.float64)
# 27th Model Train NLL:  tensor(-0.2640, dtype=torch.float64)
# 27th Model Test NLL:  tensor(1.0649, dtype=torch.float64)
# --------------------------------------------------
# 28th Model Train RMSE:  tensor(0.1577, dtype=torch.float64)
# 28th Model Test RMSE:  tensor(0.6374, dtype=torch.float64)
# 28th Model Train NLL:  tensor(-0.0646, dtype=torch.float64)
# 28th Model Test NLL:  tensor(0.8106, dtype=torch.float64)
# --------------------------------------------------
# 29th Model Train RMSE:  tensor(0.1248, dtype=torch.float64)
# 29th Model Test RMSE:  tensor(0.3293, dtype=torch.float64)
# 29th Model Train NLL:  tensor(-0.1534, dtype=torch.float64)
# 29th Model Test NLL:  tensor(0.2702, dtype=torch.float64)
# --------------------------------------------------
# 30th Model Train RMSE:  tensor(0.1142, dtype=torch.float64)
# 30th Model Test RMSE:  tensor(0.3890, dtype=torch.float64)
# 30th Model Train NLL:  tensor(-0.3060, dtype=torch.float64)
# 30th Model Test NLL:  tensor(0.5539, dtype=torch.float64)
# --------------------------------------------------
# 31th Model Train RMSE:  tensor(0.1982, dtype=torch.float64)
# 31th Model Test RMSE:  tensor(0.5359, dtype=torch.float64)
# 31th Model Train NLL:  tensor(0.0605, dtype=torch.float64)
# 31th Model Test NLL:  tensor(0.7721, dtype=torch.float64)
# --------------------------------------------------
# 32th Model Train RMSE:  tensor(0.2804, dtype=torch.float64)
# 32th Model Test RMSE:  tensor(0.6136, dtype=torch.float64)
# 32th Model Train NLL:  tensor(0.3010, dtype=torch.float64)
# 32th Model Test NLL:  tensor(0.8254, dtype=torch.float64)
# --------------------------------------------------
# 33th Model Train RMSE:  tensor(0.1752, dtype=torch.float64)
# 33th Model Test RMSE:  tensor(0.3844, dtype=torch.float64)
# 33th Model Train NLL:  tensor(0.1352, dtype=torch.float64)
# 33th Model Test NLL:  tensor(0.5565, dtype=torch.float64)
# --------------------------------------------------
# 34th Model Train RMSE:  tensor(0.1610, dtype=torch.float64)
# 34th Model Test RMSE:  tensor(0.3417, dtype=torch.float64)
# 34th Model Train NLL:  tensor(0.0028, dtype=torch.float64)
# 34th Model Test NLL:  tensor(0.3739, dtype=torch.float64)
# --------------------------------------------------
# 35th Model Train RMSE:  tensor(0.1313, dtype=torch.float64)
# 35th Model Test RMSE:  tensor(0.5732, dtype=torch.float64)
# 35th Model Train NLL:  tensor(-0.2038, dtype=torch.float64)
# 35th Model Test NLL:  tensor(0.7195, dtype=torch.float64)
# --------------------------------------------------
# 36th Model Train RMSE:  tensor(0.2184, dtype=torch.float64)
# 36th Model Test RMSE:  tensor(0.6374, dtype=torch.float64)
# 36th Model Train NLL:  tensor(0.1602, dtype=torch.float64)
# 36th Model Test NLL:  tensor(0.9995, dtype=torch.float64)
# --------------------------------------------------
# 37th Model Train RMSE:  tensor(0.2260, dtype=torch.float64)
# 37th Model Test RMSE:  tensor(0.6915, dtype=torch.float64)
# 37th Model Train NLL:  tensor(0.2557, dtype=torch.float64)
# 37th Model Test NLL:  tensor(1.1005, dtype=torch.float64)
# --------------------------------------------------
# 38th Model Train RMSE:  tensor(0.1365, dtype=torch.float64)
# 38th Model Test RMSE:  tensor(0.5238, dtype=torch.float64)
# 38th Model Train NLL:  tensor(-0.1375, dtype=torch.float64)
# 38th Model Test NLL:  tensor(0.7873, dtype=torch.float64)
# --------------------------------------------------
# 39th Model Train RMSE:  tensor(0.2851, dtype=torch.float64)
# 39th Model Test RMSE:  tensor(0.5060, dtype=torch.float64)
# 39th Model Train NLL:  tensor(0.3607, dtype=torch.float64)
# 39th Model Test NLL:  tensor(0.7252, dtype=torch.float64)
# --------------------------------------------------
# 40th Model Train RMSE:  tensor(0.1849, dtype=torch.float64)
# 40th Model Test RMSE:  tensor(0.6407, dtype=torch.float64)
# 40th Model Train NLL:  tensor(0.0472, dtype=torch.float64)
# 40th Model Test NLL:  tensor(0.8047, dtype=torch.float64)
# --------------------------------------------------
# 41th Model Train RMSE:  tensor(0.2134, dtype=torch.float64)
# 41th Model Test RMSE:  tensor(0.8562, dtype=torch.float64)
# 41th Model Train NLL:  tensor(0.1744, dtype=torch.float64)
# 41th Model Test NLL:  tensor(1.2311, dtype=torch.float64)
# --------------------------------------------------
# 42th Model Train RMSE:  tensor(0.2781, dtype=torch.float64)
# 42th Model Test RMSE:  tensor(0.4973, dtype=torch.float64)
# 42th Model Train NLL:  tensor(0.4351, dtype=torch.float64)
# 42th Model Test NLL:  tensor(0.7755, dtype=torch.float64)
# --------------------------------------------------
# 43th Model Train RMSE:  tensor(0.2469, dtype=torch.float64)
# 43th Model Test RMSE:  tensor(0.4697, dtype=torch.float64)
# 43th Model Train NLL:  tensor(0.3840, dtype=torch.float64)
# 43th Model Test NLL:  tensor(0.7359, dtype=torch.float64)
# --------------------------------------------------
# 44th Model Train RMSE:  tensor(0.1949, dtype=torch.float64)
# 44th Model Test RMSE:  tensor(0.5698, dtype=torch.float64)
# 44th Model Train NLL:  tensor(0.1704, dtype=torch.float64)
# 44th Model Test NLL:  tensor(0.7147, dtype=torch.float64)
# --------------------------------------------------
# 45th Model Train RMSE:  tensor(0.1406, dtype=torch.float64)
# 45th Model Test RMSE:  tensor(0.6476, dtype=torch.float64)
# 45th Model Train NLL:  tensor(-0.1794, dtype=torch.float64)
# 45th Model Test NLL:  tensor(1.0088, dtype=torch.float64)
# --------------------------------------------------
# 46th Model Train RMSE:  tensor(0.2692, dtype=torch.float64)
# 46th Model Test RMSE:  tensor(0.3321, dtype=torch.float64)
# 46th Model Train NLL:  tensor(0.3541, dtype=torch.float64)
# 46th Model Test NLL:  tensor(0.5113, dtype=torch.float64)
# --------------------------------------------------
# 47th Model Train RMSE:  tensor(0.2347, dtype=torch.float64)
# 47th Model Test RMSE:  tensor(0.5066, dtype=torch.float64)
# 47th Model Train NLL:  tensor(0.2341, dtype=torch.float64)
# 47th Model Test NLL:  tensor(0.6061, dtype=torch.float64)
# --------------------------------------------------
# 48th Model Train RMSE:  tensor(0.0775, dtype=torch.float64)
# 48th Model Test RMSE:  tensor(0.6742, dtype=torch.float64)
# 48th Model Train NLL:  tensor(-0.5730, dtype=torch.float64)
# 48th Model Test NLL:  tensor(1.3715, dtype=torch.float64)
# --------------------------------------------------
# 49th Model Train RMSE:  tensor(0.2149, dtype=torch.float64)
# 49th Model Test RMSE:  tensor(0.4534, dtype=torch.float64)
# 49th Model Train NLL:  tensor(0.2739, dtype=torch.float64)
# 49th Model Test NLL:  tensor(0.7013, dtype=torch.float64)
# ######################################################################
# Global Train RMSE tensor(0.2095, dtype=torch.float64)
# Global Test RMSE tensor(0.5791, dtype=torch.float64)
# Global Train NLL tensor(0.0428, dtype=torch.float64)
# Global Test NLL tensor(0.8038, dtype=torch.float64)

# %% [markdown]
# ## Plot

# %%
picked_index = 49 # 18

plot_traindata_testdata_fittedgp(train_X=list_train_X[picked_index], 
                                 train_Y=list_train_Y[picked_index], 
                                 test_X=list_test_X[picked_index], 
                                 test_Y=list_test_Y[picked_index], 
                                 gp_X=tensor_inputs4visualization, 
                                 gp_pred_mean=list_output_dist4visual[picked_index].loc.detach(), 
                                 gp_pred_std=list_output_dist4visual[picked_index].stddev.detach(), 
                                 inducing_points_X=MultiIGP.get_model(picked_index).variational_strategy.inducing_points.detach(), 
                                 n_inducing_C=config['n_inducing_input'], # NOTE: input is C not X
                                 title='Independent SVGP, #18')
