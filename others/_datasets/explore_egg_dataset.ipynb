# %%
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
all_path = '/Users/jiangxiaoyu/Desktop/All Projects/Scalable_LVMOGP/data/egg_datasets/egg_all.csv'
train_path = '/Users/jiangxiaoyu/Desktop/All Projects/Scalable_LVMOGP/data/egg_datasets/egg_train.csv'

df_all = pd.read_csv(all_path)
train_all = pd.read_csv(train_path)

# %%
plt.plot(df_all.iloc[:, 6])

# %%
print('The number of training data: ', (train_all.iloc[:, 1:].notna()).sum().sum())
# Out:
# The number of training data:  1492
