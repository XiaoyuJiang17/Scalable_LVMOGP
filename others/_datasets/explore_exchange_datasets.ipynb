# %%
import pandas as pd
import numpy as np

# %%
rates = pd.read_csv('/Users/jiangxiaoyu/Desktop/All Projects/Scalable_LVMOGP/data/exchange/exchange_rates.csv')
train = pd.read_csv('/Users/jiangxiaoyu/Desktop/All Projects/Scalable_LVMOGP/data/exchange/exchange_train.csv')
test = pd.read_csv('/Users/jiangxiaoyu/Desktop/All Projects/Scalable_LVMOGP/data/exchange/exchange_test.csv')

# %%
# we are interested in USD/CAD	;  USD/JPY  ;  USD/AUD

# %%
train.isna().sum()
# Out:
# year         0
# USD/CHF      0
# USD/EUR      0
# USD/GBP      0
# USD/HKD      0
# USD/KRW      0
# USD/MXN      0
# USD/NZD      0
# USD/XAG      8
# USD/XAU      9
# USD/XPT     42
# USD/CAD     51
# USD/JPY    101
# USD/AUD    151
# dtype: int64

# %%
train.index[train['USD/XAU'].isna()]
# Out:
# Index([0, 68, 88, 102, 131, 165, 247, 249, 250], dtype='int64')

# %%
(rates - rates.mean()) / rates.std()
# Out:
#          year   USD/CHF   USD/EUR   USD/GBP   USD/HKD   USD/KRW   USD/MXN  \
# 0   -1.699044 -0.342639 -0.778051 -0.707256  1.049742  0.384535  1.252689
# 1   -1.689536 -0.686024 -0.998590 -1.305463  0.717495  0.281162  1.361630
# 2   -1.680028 -0.811902 -1.141424 -1.451347  0.630919 -0.255069  0.513864
# 3   -1.670520 -0.936741 -1.309645 -1.799110  0.515547 -0.526780 -0.301969
# 4   -1.641995 -0.917227 -1.275612 -1.600177  0.337820 -0.918177 -0.390803
# ..        ...       ...       ...       ...       ...       ...       ...
# 246  1.657337  1.145557  1.238264 -0.465488  0.045179 -1.149089  0.861009
# 247  1.685862  1.139986  1.327649 -0.612413 -0.179986 -0.995277  0.935748
# 248  1.714386  1.589002  1.689992 -0.277605  0.016419 -1.137425  0.472716
# 249  1.723894  1.986049  1.905095 -0.216341 -0.146468 -0.718481  0.234801
# 250  1.752419  1.816784  1.691593 -0.452541  0.150669 -0.652705  0.071458
#
#       USD/NZD   USD/XAG   USD/XAU   USD/XPT   USD/CAD   USD/JPY   USD/AUD
# ...
